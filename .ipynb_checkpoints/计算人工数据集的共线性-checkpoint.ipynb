# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1

# %%
def PC(df):
    """
    Calculate the pairwise correlation coefficients for each column in a DataFrame.

    """
    return df.corr()

# %% [markdown]
# 2

# %%
def calculate_condition_index(df):
    # Step 1: Compute the correlation matrix
    corr_matrix = df.corr()

    # Step 2: Compute eigenvalues of the correlation matrix
    eigenvalues, _ = np.linalg.eig(corr_matrix)

    # Step 3: Sort eigenvalues in descending order (for clarity)
    sorted_eigenvalues = np.sort(eigenvalues)[::-1]

    # Step 4: Compute condition index as sqrt(largest_eigenvalue / current_eigenvalue)
    max_eigenvalue = sorted_eigenvalues[0]
    condition_indices = [np.sqrt(max_eigenvalue / ev) for ev in sorted_eigenvalues]
    
    # Step 5: Find the maximum Condition Index
    max_condition_index = max(condition_indices)
    
    # Step 5: Return condition indices as a DataFrame
    condition_index_df = pd.DataFrame({
        'Eigenvalue': sorted_eigenvalues,
        'Condition Index': condition_indices
    })

    return condition_index_df, max_condition_index

# %% [markdown]
# 3

# %%
def calculate_vif1(df):
    # Initialize a DataFrame to store the VIF for each variable
    vif_data = pd.DataFrame()
    vif_data["Variable"] = df.columns
    vif_values = []

    for i in range(df.shape[1]):
        # Take the i-th column as the dependent variable, and the remaining columns as independent variables
        y = df.iloc[:, i]
        X = df.drop(df.columns[i], axis=1)

        # Calculate the R^2 value: beta = (X^T X)^(-1) X^T y
        X = np.column_stack([np.ones(X.shape[0]), X])  # Add an intercept term
        beta = np.linalg.lstsq(X, y, rcond=None)[0]  # Solve for the least squares solution
        y_pred = X @ beta  # Predicted values
        r_squared = 1 - np.sum((y - y_pred) ** 2) / np.sum((y - y.mean()) ** 2)

        # Calculate the VIF value
        vif = 1 / (1 - r_squared)
        vif_values.append(vif)

    vif_data["VIF"] = vif_values
    return vif_data

# %% [markdown]
# 4

# %%
def calculate_variance_decomposition(df):
    # Step 1: Calculate the covariance matrix
    cov_matrix = df.cov()

    # Step 2: Calculate eigenvalues and eigenvectors of the covariance matrix
    eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

    # Step 3: Compute the variance decomposition proportions for each variable
    variance_decomposition = []
    for i in range(len(df.columns)):
        # Compute the variance proportion of the i-th variable for each eigenvalue
        proportions = (eigenvectors[i, :] ** 2) * eigenvalues / cov_matrix.iloc[i, i]
        variance_decomposition.append(proportions / proportions.sum())

    # Convert results to a DataFrame
    variance_decomposition_df = pd.DataFrame(
        variance_decomposition, 
        columns=[f'Eigenvalue_{j+1}' for j in range(len(eigenvalues))],
        index=df.columns
    )
    return variance_decomposition_df

# %% [markdown]
# 5

# %%
def calculate_determinant_of_correlation_matrix(df):
    # Step 1: Compute the correlation matrix
    corr_matrix = df.corr()

    # Step 2: Compute eigenvalues of the correlation matrix
    eigenvalues = np.linalg.eigvals(corr_matrix)

    # Step 3: Calculate the determinant as the product of the eigenvalues
    determinant = np.prod(eigenvalues)

    return determinant

# %% [markdown]
# 第一个数据集共线性不强，不必分析

# %%
file_path = 'METHOD_BUILT_ALL_RHO_MATRIX.xlsx'  # 替换为你的文件路径
df1 = pd.read_excel(file_path)
df1 = df1.apply(np.log)
df1.fillna(df1.mean(), inplace=True)  # 用均值填充
df1.fillna(df1.median(), inplace=True)  # 用中位数填充

print(df1.isna().sum())  # 检查每列 NaN 值的数量
print(np.isinf(df1).sum())  # 检查 Inf 值

print(PC(df1))
# Compute condition index
cond_index, max_condition_index = calculate_condition_index(df1)
print(cond_index)
print(max_condition_index)
r = calculate_vif1(df1)
print(r)
vd_df = calculate_variance_decomposition(df1)
print(vd_df)
D = calculate_determinant_of_correlation_matrix(df1)
print("Determinant of the Correlation Matrix (D):", D)
# Out:
# y     0
# x1    0
# x2    0
# x3    0
# x4    0
# dtype: int64
# y     0
# x1    0
# x2    0
# x3    0
# x4    0
# dtype: int64
#            y        x1        x2        x3        x4
# y   1.000000  0.562771  0.296347  0.403551  0.376560
# x1  0.562771  1.000000  0.213782  0.738732  0.159443
# x2  0.296347  0.213782  1.000000  0.538900  0.616268
# x3  0.403551  0.738732  0.538900  1.000000  0.317926
# x4  0.376560  0.159443  0.616268  0.317926  1.000000
#    Eigenvalue  Condition Index
# 0    2.704458         1.000000
# 1    1.132885         1.545067
# 2    0.681507         1.992072
# 3    0.332484         2.852036
# 4    0.148667         4.265142
# 4.265141555638201
#   Variable       VIF
# 0        y  1.721033
# 1       x1  3.258947
# 2       x2  2.288762
# 3       x3  3.429646
# 4       x4  1.755539
#     Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4  Eigenvalue_5
# y       0.224181      0.093809      0.062336  3.014969e-01      0.318177
# x1      0.383073      0.594317      0.022584  8.351008e-06      0.000017
# x2      0.795414      0.201724      0.002848  5.389138e-07      0.000014
# x3      0.675050      0.145356      0.179570  3.345312e-06      0.000021
# x4      0.310896      0.067002      0.010710  1.540067e-01      0.457386
# Determinant of the Correlation Matrix (D): 0.10320954509518844

# %% [markdown]
# 第二个有了一定共线性

# %%
file_path = 'METHOD_DIFF_FUN_1.xlsx'  # 替换为你的文件路径
df1 = pd.read_excel(file_path)
df1 = df1[['x1','x2','x3',"x4"]] 
print(PC(df1))
# Compute condition index
cond_index, max_condition_index = calculate_condition_index(df1)
print(cond_index)
print(max_condition_index)
r = calculate_vif1(df1)
print(r)
vd_df = calculate_variance_decomposition(df1)
print(vd_df)
D = calculate_determinant_of_correlation_matrix(df1)
print("Determinant of the Correlation Matrix (D):", D)
# Out:
#           x1        x2        x3        x4
# x1  1.000000 -0.005156 -0.017734 -0.024587
# x2 -0.005156  1.000000  0.008771 -0.019293
# x3 -0.017734  0.008771  1.000000 -0.001354
# x4 -0.024587 -0.019293 -0.001354  1.000000
#    Eigenvalue  Condition Index
# 0    1.030563         1.000000
# 1    1.019556         1.005384
# 2    0.985443         1.022637
# 3    0.964438         1.033714
# 1.0337135183359456
#   Variable       VIF
# 0       x1  1.000951
# 1       x2  1.000479
# 2       x3  1.000393
# 3       x4  1.000985
#     Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4
# x1      0.000360  7.571344e-03      0.991898  1.704758e-04
# x2      0.000085  1.396154e-03      0.000456  9.980630e-01
# x3      0.999998  1.601077e-09      0.000002  1.550020e-07
# x4      0.000002  9.957527e-01      0.003871  3.745813e-04
# Determinant of the Correlation Matrix (D): 0.9985997435528587

# %% [markdown]
# 第三个

# %%
for i in range(10):
    file_path = 'METHOD_DIFF_FUN_'+str(i+1)+'.xlsx'  # 替换为你的文件路径
    df1 = pd.read_excel(file_path)
    df1 = df1[['x1','x2','x3',"x4"]] 
    print("==============================================================================")
    print("file_path")
    print(PC(df1))
    # Compute condition index
    cond_index, max_condition_index = calculate_condition_index(df1)
    print(cond_index)
    print(max_condition_index)
    r = calculate_vif1(df1)
    print(r)
    vd_df = calculate_variance_decomposition(df1)
    print(vd_df)
    D = calculate_determinant_of_correlation_matrix(df1)
    print("Determinant of the Correlation Matrix (D):", D)
    print("==============================================================================")
# Out:
# ==============================================================================
# file_path
#           x1        x2        x3        x4
# x1  1.000000 -0.005156 -0.017734 -0.024587
# x2 -0.005156  1.000000  0.008771 -0.019293
# x3 -0.017734  0.008771  1.000000 -0.001354
# x4 -0.024587 -0.019293 -0.001354  1.000000
#    Eigenvalue  Condition Index
# 0    1.030563         1.000000
# 1    1.019556         1.005384
# 2    0.985443         1.022637
# 3    0.964438         1.033714
# 1.0337135183359456
#   Variable       VIF
# 0       x1  1.000951
# 1       x2  1.000479
# 2       x3  1.000393
# 3       x4  1.000985
#     Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4
# x1      0.000360  7.571344e-03      0.991898  1.704758e-04
# x2      0.000085  1.396154e-03      0.000456  9.980630e-01
# x3      0.999998  1.601077e-09      0.000002  1.550020e-07
# x4      0.000002  9.957527e-01      0.003871  3.745813e-04
# Determinant of the Correlation Matrix (D): 0.9985997435528587
# ==============================================================================
# ==============================================================================
# file_path
#           x1        x2        x3        x4
# x1  1.000000  0.694113  0.488116  0.323561
# x2  0.694113  1.000000  0.699115  0.485545
# x3  0.488116  0.699115  1.000000  0.696733
# x4  0.323561  0.485545  0.696733  1.000000
#    Eigenvalue  Condition Index
# 0    2.708412         1.000000
# 1    0.769325         1.876300
# 2    0.314295         2.935545
# 3    0.207968         3.608766
# 3.608765862523902
#   Variable       VIF
# 0       x1  1.931522
# 1       x2  2.875981
# 2       x3  2.906555
# 3       x4  1.945154
#     Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4
# x1      0.266888      0.035309      0.640648      0.057155
# x2      0.519259      0.236069      0.226793      0.017880
# x3      0.996738      0.000052      0.000418      0.002792
# x4      0.527615      0.000008      0.065425      0.406952
# Determinant of the Correlation Matrix (D): 0.13619432068388493
# ==============================================================================
# ==============================================================================
# file_path
#           x1        x2        x3        x4
# x1  1.000000  0.705094  0.481342  0.353433
# x2  0.705094  1.000000  0.675345  0.484463
# x3  0.481342  0.675345  1.000000  0.708980
# x4  0.353433  0.484463  0.708980  1.000000
#    Eigenvalue  Condition Index
# 0    2.715169         1.000000
# 1    0.761557         1.888197
# 2    0.313621         2.942361
# 3    0.209654         3.598710
# 3.598710227598354
#   Variable       VIF
# 0       x1  1.989425
# 1       x2  2.809442
# 2       x3  2.829410
# 3       x4  2.011451
#     Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4
# x1      0.266822      0.034641      0.695832      0.002704
# x2      0.491789      0.238149      0.270048      0.000014
# x3      0.995713      0.000060      0.001550      0.002677
# x4      0.550615      0.000009      0.005877      0.443499
# Determinant of the Correlation Matrix (D): 0.13595870118155767
# ==============================================================================
# ==============================================================================
# file_path
#           x1        x2        x3        x4
# x1  1.000000  0.693048  0.466951  0.321605
# x2  0.693048  1.000000  0.702049  0.465995
# x3  0.466951  0.702049  1.000000  0.677816
# x4  0.321605  0.465995  0.677816  1.000000
#    Eigenvalue  Condition Index
# 0    2.679364         1.000000
# 1    0.778205         1.855534
# 2    0.344654         2.788203
# 3    0.197778         3.680672
# 3.6806718683205175
#   Variable       VIF
# 0       x1  1.928076
# 1       x2  2.973844
# 2       x3  2.862398
# 3       x4  1.851556
#     Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4
# x1      0.251462      0.036356      0.701789      0.010394
# x2      0.527861      0.223410      0.248602      0.000127
# x3      0.996242      0.000089      0.001319      0.002350
# x4      0.501938      0.000092      0.015024      0.482945
# Determinant of the Correlation Matrix (D): 0.14213009448467476
# ==============================================================================
# ==============================================================================
# file_path
#           x1        x2        x3        x4
# x1  1.000000  0.499401  0.488883  0.499213
# x2  0.499401  1.000000  0.489504  0.492599
# x3  0.488883  0.489504  1.000000  0.505627
# x4  0.499213  0.492599  0.505627  1.000000
#    Eigenvalue  Condition Index
# 0    2.487632         1.000000
# 1    0.518460         2.190460
# 2    0.502251         2.225526
# 3    0.491656         2.249377
# 2.2493768664173137
#   Variable       VIF
# 0       x1  1.588526
# 1       x2  1.579131
# 2       x3  1.583603
# 3       x4  1.604492
#     Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4
# x1      0.280278      0.300593      0.366757      0.052372
# x2      0.274596      0.197374      0.050800      0.477230
# x3      0.995533      0.004417      0.000038      0.000012
# x4      0.306929      0.557276      0.131010      0.004785
# Determinant of the Correlation Matrix (D): 0.31848163254600703
# ==============================================================================
# ==============================================================================
# file_path
#           x1        x2        x3        x4
# x1  1.000000  0.698950 -0.034989 -0.021528
# x2  0.698950  1.000000 -0.013466  0.003122
# x3 -0.034989 -0.013466  1.000000 -0.005140
# x4 -0.021528  0.003122 -0.005140  1.000000
#    Eigenvalue  Condition Index
# 0    1.700858         1.000000
# 1    1.004873         1.301003
# 2    0.993990         1.308106
# 3    0.300279         2.379972
# 2.3799723276243996
#   Variable       VIF
# 0       x1  1.959837
# 1       x2  1.956888
# 2       x3  1.001502
# 3       x4  1.001150
#     Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4
# x1      0.001431  7.887978e-02      0.869864  4.982533e-02
# x2      0.000249  2.394741e-01      0.729084  3.119284e-02
# x3      0.999991  1.360605e-07      0.000008  1.695023e-08
# x4      0.000032  3.151736e-05      0.043696  9.562410e-01
# Determinant of the Correlation Matrix (D): 0.5101356880129658
# ==============================================================================
# ==============================================================================
# file_path
#           x1        x2        x3        x4
# x1  1.000000  0.687905  0.495403 -0.019363
# x2  0.687905  1.000000  0.708160 -0.002219
# x3  0.495403  0.708160  1.000000  0.003183
# x4 -0.019363 -0.002219  0.003183  1.000000
#    Eigenvalue  Condition Index
# 0    2.265598         1.000000
# 1    1.000473         1.504834
# 2    0.504487         2.119172
# 3    0.229441         3.142361
# 3.1423606633233527
#   Variable       VIF
# 0       x1  1.899951
# 1       x2  2.874330
# 2       x3  2.006600
# 3       x4  1.000660
#     Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4
# x1      0.277886      0.036743      0.683496      0.001875
# x2      0.535210      0.236512      0.228020      0.000258
# x3      0.998363      0.000063      0.001571      0.000002
# x4      0.000007      0.000004      0.000719      0.999271
# Determinant of the Correlation Matrix (D): 0.2623672789763492
# ==============================================================================
# ==============================================================================
# file_path
#           x1        x2        x3        x4
# x1  1.000000  0.903544  0.011602  0.019815
# x2  0.903544  1.000000  0.016303  0.023185
# x3  0.011602  0.016303  1.000000  0.907511
# x4  0.019815  0.023185  0.907511  1.000000
#    Eigenvalue  Condition Index
# 0    1.941055         1.000000
# 1    1.870041         1.018810
# 2    0.096555         4.483656
# 3    0.092349         4.584606
# 4.584606129644811
#   Variable       VIF
# 0       x1  5.447183
# 1       x2  5.447408
# 2       x3  5.669669
# 3       x4  5.670947
#     Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4
# x1      0.000186      0.971073  2.873307e-02      0.000009
# x2      0.000333      0.927223  7.241461e-02      0.000030
# x3      0.998981      0.000005  1.087830e-08      0.001014
# x4      0.847219      0.000075  4.388699e-07      0.152706
# Determinant of the Correlation Matrix (D): 0.03236652064426661
# ==============================================================================
# ==============================================================================
# file_path
#           x1        x2        x3        x4
# x1  1.000000  0.792183  0.034547  0.033691
# x2  0.792183  1.000000  0.023206  0.041949
# x3  0.034547  0.023206  1.000000 -0.006793
# x4  0.033691  0.041949 -0.006793  1.000000
#    Eigenvalue  Condition Index
# 0    1.797813         1.000000
# 1    1.006843         1.336261
# 2    0.987651         1.349182
# 3    0.207694         2.942119
# 2.9421188200990445
#   Variable       VIF
# 0       x1  2.686838
# 1       x2  2.686749
# 2       x3  1.001302
# 3       x4  1.001824
#     Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4
# x1      0.001410  6.314636e-02      0.546024      0.389419
# x2      0.000674  1.532419e-01      0.503897      0.342187
# x3      0.999990  2.266622e-08      0.000004      0.000006
# x4      0.000054  3.874838e-06      0.450568      0.549375
# Determinant of the Correlation Matrix (D): 0.3713072371086027
# ==============================================================================
# ==============================================================================
# file_path
#           x1        x2        x3        x4
# x1  1.000000  0.686734  0.491668  0.335939
# x2  0.686734  1.000000  0.718305  0.479730
# x3  0.491668  0.718305  1.000000  0.690408
# x4  0.335939  0.479730  0.690408  1.000000
#    Eigenvalue  Condition Index
# 0    2.716867         1.000000
# 1    0.751695         1.901137
# 2    0.337470         2.837376
# 3    0.193968         3.742564
# 3.742564081487338
#   Variable       VIF
# 0       x1  1.892938
# 1       x2  2.968332
# 2       x3  3.042648
# 3       x4  1.913201
#     Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4
# x1      0.271340      0.030968      0.652092      0.045601
# x2      0.544859      0.236939      0.213315      0.004887
# x3      0.996879      0.000073      0.000571      0.002476
# x4      0.517163      0.000086      0.048459      0.434293
# Determinant of the Correlation Matrix (D): 0.13368254828234896
# ==============================================================================

# %%
for i in range(8):
    file_path = 'METHOD_MULTICOLLINEAR_'+str(i+1)+'.xlsx'  # 替换为你的文件路径
    df1 = pd.read_excel(file_path)
    #df1 = df1[['x1','x2','x3',"x4"]] 
    print("==============================================================================")
    print("file_path")
    print(PC(df1))
    # Compute condition index
    cond_index, max_condition_index = calculate_condition_index(df1)
    print(cond_index)
    print(max_condition_index)
    r = calculate_vif1(df1)
    print(r)
    vd_df = calculate_variance_decomposition(df1)
    print(vd_df)
    D = calculate_determinant_of_correlation_matrix(df1)
    print("Determinant of the Correlation Matrix (D):", D)
    print("==============================================================================")
# Out:
# ==============================================================================
# file_path
#            y        x1        x2        x3        x4
# y   1.000000  0.767996  0.594476  0.644954  0.407327
# x1  0.767996  1.000000  0.261934  0.970686 -0.036633
# x2  0.594476  0.261934  1.000000  0.041787 -0.003915
# x3  0.644954  0.970686  0.041787  1.000000 -0.037126
# x4  0.407327 -0.036633 -0.003915 -0.037126  1.000000
#    Eigenvalue  Condition Index
# 0    2.765788         1.000000
# 1    1.212812         1.510124
# 2    0.979183         1.680651
# 3    0.039265         8.392772
# 4    0.002952        30.609279
# 30.60927881731557
#   Variable         VIF
# 0        y   22.723543
# 1       x1  193.685117
# 2       x2    7.232054
# 3       x3  137.522032
# 4       x4    5.268630
#     Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4  Eigenvalue_5
# y       0.726699      0.272461      0.000284  5.305182e-04      0.000025
# x1      0.978438      0.020355      0.000961  5.173135e-05      0.000194
# x2      0.111280      0.390011      0.443291  4.850338e-02      0.006914
# x3      0.886895      0.094287      0.016171  9.574001e-07      0.002646
# x4      0.005780      0.414645      0.520025  5.725273e-02      0.002298
# Determinant of the Correlation Matrix (D): 0.0003807122847668349
# ==============================================================================
# ==============================================================================
# file_path
#            y        x1        x2        x3        x4
# y   1.000000  0.961664  0.550316  0.901952  0.798990
# x1  0.961664  1.000000  0.413542  0.976136  0.841295
# x2  0.550316  0.413542  1.000000  0.226516  0.026901
# x3  0.901952  0.976136  0.226516  1.000000  0.900928
# x4  0.798990  0.841295  0.026901  0.900928  1.000000
#    Eigenvalue  Condition Index
# 0    3.828417         1.000000
# 1    1.040251         1.918406
# 2    0.100363         6.176225
# 3    0.028175        11.656679
# 4    0.002794        37.017342
# 37.01734206668086
#   Variable         VIF
# 0        y   37.887171
# 1       x1  203.712493
# 2       x2    6.919698
# 3       x3  144.997009
# 4       x4   11.086318
#     Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4  Eigenvalue_5
# y       0.962790      0.033789      0.003344      0.000057      0.000020
# x1      0.992414      0.004929      0.002507      0.000012      0.000138
# x2      0.200016      0.565465      0.194664      0.037121      0.002734
# x3      0.930378      0.065341      0.001739      0.000288      0.002254
# x4      0.713376      0.076718      0.159663      0.040673      0.009570
# Determinant of the Correlation Matrix (D): 3.146361604552119e-05
# ==============================================================================
# ==============================================================================
# file_path
#            y        x1        x2        x3        x4
# y   1.000000  0.883237  0.763493  0.783374  0.887263
# x1  0.883237  1.000000  0.475606  0.977271  0.691261
# x2  0.763493  0.475606  1.000000  0.299606  0.704738
# x3  0.783374  0.977271  0.299606  1.000000  0.598436
# x4  0.887263  0.691261  0.704738  0.598436  1.000000
#    Eigenvalue  Condition Index
# 0    3.861935         1.000000
# 1    0.875251         2.100565
# 2    0.231906         4.080812
# 3    0.027880        11.769368
# 4    0.003028        35.713244
# 35.71324359248741
#   Variable         VIF
# 0        y   38.301443
# 1       x1  192.203438
# 2       x2    7.439271
# 3       x3  126.749278
# 4       x4    7.145883
#     Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4  Eigenvalue_5
# y       0.901986      0.097556      0.000182      0.000264      0.000012
# x1      0.971217      0.028025      0.000583      0.000017      0.000159
# x2      0.347074      0.460648      0.141260      0.040910      0.010107
# x3      0.876097      0.116481      0.004913      0.000033      0.002475
# x4      0.615568      0.208573      0.095775      0.075588      0.004496
# Determinant of the Correlation Matrix (D): 6.617505197916068e-05
# ==============================================================================
# ==============================================================================
# file_path
#            y        x1        x2        x3        x4
# y   1.000000  0.910311  0.860772  0.874076  0.365864
# x1  0.910311  1.000000  0.854926  0.988897  0.036911
# x2  0.860772  0.854926  1.000000  0.788515  0.022531
# x3  0.874076  0.988897  0.788515  1.000000  0.038840
# x4  0.365864  0.036911  0.022531  0.038840  1.000000
#    Eigenvalue  Condition Index
# 0    3.661527         1.000000
# 1    1.066435         1.852951
# 2    0.240674         3.900463
# 3    0.028786        11.278174
# 4    0.002578        37.686509
# 37.68650872218681
#   Variable         VIF
# 0        y   38.684166
# 1       x1  245.691649
# 2       x2    8.847577
# 3       x3  129.404029
# 4       x4    5.368152
#     Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4  Eigenvalue_5
# y       0.913866      0.085582      0.000315      0.000218      0.000019
# x1      0.983282      0.016506      0.000027      0.000029      0.000157
# x2      0.757923      0.006848      0.172572      0.054713      0.007944
# x3      0.948716      0.035836      0.012710      0.000046      0.002692
# x4      0.020861      0.673473      0.262591      0.039940      0.003136
# Determinant of the Correlation Matrix (D): 6.974310958647058e-05
# ==============================================================================
# ==============================================================================
# file_path
#            y        x1        x2        x3        x4
# y   1.000000  0.960630  0.922589  0.927265  0.905059
# x1  0.960630  1.000000  0.862771  0.990008  0.824976
# x2  0.922589  0.862771  1.000000  0.802098  0.818894
# x3  0.927265  0.990008  0.802098  1.000000  0.798576
# x4  0.905059  0.824976  0.818894  0.798576  1.000000
#    Eigenvalue  Condition Index
# 0    4.529443         1.000000
# 1    0.264773         4.136047
# 2    0.181491         4.995687
# 3    0.021562        14.493685
# 4    0.002732        40.718803
# 40.71880325773046
#   Variable         VIF
# 0        y   50.552871
# 1       x1  226.636527
# 2       x2   10.108272
# 3       x3  127.156924
# 4       x4    7.485107
#     Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4  Eigenvalue_5
# y       0.972330      0.027493      0.000005      0.000169      0.000004
# x1      0.986807      0.012818      0.000123      0.000044      0.000208
# x2      0.800166      0.069386      0.012899      0.048564      0.068985
# x3      0.950019      0.042682      0.002403      0.000170      0.004726
# x4      0.753821      0.095681      0.002532      0.049357      0.098609
# Determinant of the Correlation Matrix (D): 1.282078626635518e-05
# ==============================================================================
# ==============================================================================
# file_path
#            y        x1        x2        x3        x4
# y   1.000000  0.983027  0.286209  0.988285  0.955821
# x1  0.983027  1.000000  0.405928  0.980363  0.897545
# x2  0.286209  0.405928  1.000000  0.229369  0.015142
# x3  0.988285  0.980363  0.229369  1.000000  0.955644
# x4  0.955821  0.897545  0.015142  0.955644  1.000000
#    Eigenvalue  Condition Index
# 0    3.956273         1.000000
# 1    1.009619         1.979541
# 2    0.028564        11.768939
# 3    0.004138        30.919071
# 4    0.001407        53.032043
# 53.03204327704034
#   Variable         VIF
# 0        y  261.389255
# 1       x1  358.609976
# 2       x2   11.269271
# 3       x3  248.959566
# 4       x4  108.534196
#     Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4  Eigenvalue_5
# y       0.998573      0.000863      0.000545      0.000019  1.378148e-07
# x1      0.977889      0.020507      0.001559      0.000021  2.406801e-05
# x2      0.091903      0.709475      0.146160      0.046621  5.840778e-03
# x3      0.981886      0.000781      0.014784      0.000438  2.111514e-03
# x4      0.900927      0.093378      0.003929      0.001753  1.461466e-05
# Determinant of the Correlation Matrix (D): 6.641986860516147e-07
# ==============================================================================
# ==============================================================================
# file_path
#            y        x1        x2        x3        x4
# y   1.000000  0.990618  0.815564  0.990861  0.974945
# x1  0.990618  1.000000  0.854870  0.993265  0.944204
# x2  0.815564  0.854870  1.000000  0.799657  0.688695
# x3  0.990861  0.993265  0.799657  1.000000  0.964454
# x4  0.974945  0.944204  0.688695  0.964454  1.000000
#    Eigenvalue  Condition Index
# 0    4.619653         1.000000
# 1    0.348240         3.642211
# 2    0.027365        12.992994
# 3    0.003669        35.485305
# 4    0.001073        65.604288
# 65.60428770014465
#   Variable         VIF
# 0        y  343.141712
# 1       x1  508.482721
# 2       x2   13.317047
# 3       x3  279.697977
# 4       x4   99.223043
#     Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4  Eigenvalue_5
# y       0.998772      0.000965      0.000251      0.000012  1.874992e-07
# x1      0.989424      0.010097      0.000447      0.000012  1.919830e-05
# x2      0.679677      0.167674      0.101965      0.044991  5.692961e-03
# x3      0.987667      0.000863      0.009202      0.000414  1.853125e-03
# x4      0.940932      0.050564      0.007006      0.001476  2.219843e-05
# Determinant of the Correlation Matrix (D): 1.7335502096152406e-07
# ==============================================================================
# ==============================================================================
# file_path
#            y        x1        x2        x3        x4
# y   1.000000  0.789467  0.521054  0.695491  0.311694
# x1  0.789467  1.000000  0.144583  0.969824 -0.071267
# x2  0.521054  0.144583  1.000000 -0.068293 -0.025115
# x3  0.695491  0.969824 -0.068293  1.000000  0.008433
# x4  0.311694 -0.071267 -0.025115  0.008433  1.000000
#    Eigenvalue  Condition Index
# 0    2.718454         1.000000
# 1    1.195309         1.508068
# 2    1.036386         1.619572
# 3    0.046744         7.626056
# 4    0.003107        29.580762
# 29.580761737351335
#   Variable         VIF
# 0        y   18.860196
# 1       x1  181.332012
# 2       x2    6.270881
# 3       x3  133.277213
# 4       x4    5.704340
#     Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4  Eigenvalue_5
# y       0.735895      0.263001      0.000334      0.000740      0.000030
# x1      0.984197      0.013954      0.001635      0.000044      0.000169
# x2      0.041960      0.503419      0.361216      0.086524      0.006881
# x3      0.912200      0.061130      0.024439      0.000028      0.002203
# x4      0.000570      0.304768      0.638207      0.049421      0.007034
# Determinant of the Correlation Matrix (D): 0.0004890454637157642
# ==============================================================================

# %%
file_path = 'METHOD_4_CHANGE_COLL.xlsx'  # 替换为你的文件路径
df1 = pd.read_excel(file_path)
print(PC(df1))
# Compute condition index
cond_index, max_condition_index = calculate_condition_index(df1)
print(cond_index)
print(max_condition_index)
r = calculate_vif1(df1)
print(r)
vd_df = calculate_variance_decomposition(df1)
print(vd_df)
D = calculate_determinant_of_correlation_matrix(df1)
print("Determinant of the Correlation Matrix (D):", D)
# Out:
#                     y        x1        x2        x3        x4  x1_quantile
# y            1.000000  0.698790  0.687545  0.473542  0.262893     0.055235
# x1           0.698790  1.000000  0.174031  0.051760  0.008612     0.089940
# x2           0.687545  0.174031  1.000000  0.485607  0.247285     0.000137
# x3           0.473542  0.051760  0.485607  1.000000  0.662670     0.096422
# x4           0.262893  0.008612  0.247285  0.662670  1.000000     0.099667
# x1_quantile  0.055235  0.089940  0.000137  0.096422  0.099667     1.000000
#    Eigenvalue  Condition Index
# 0    2.593054         1.000000
# 1    1.342760         1.389654
# 2    1.017041         1.596749
# 3    0.677667         1.956130
# 4    0.282147         3.031574
# 5    0.087331         5.449059
# 5.449059055019367
#       Variable       VIF
# 0            y  6.765839
# 1           x1  3.529183
# 2           x2  2.926516
# 3           x3  2.526026
# 4           x4  1.810283
# 5  x1_quantile  1.026367
#              Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4  \
# y                0.080372      0.919089  1.241278e-04  6.834477e-05
# x1               0.000559      0.522941  3.328659e-01  2.147213e-02
# x2               0.068501      0.425561  4.504788e-01  8.312206e-04
# x3               0.448429      0.088561  6.381183e-02  2.908063e-01
# x4               0.999540      0.000459  4.712004e-07  7.562850e-08
# x1_quantile      0.010080      0.000833  2.004947e-02  1.356480e-03
#
#              Eigenvalue_5  Eigenvalue_6
# y            3.354896e-04  1.115666e-05
# x1           1.221622e-01  2.166649e-08
# x2           5.121580e-02  3.412389e-03
# x3           1.037135e-01  4.678332e-03
# x4           1.202565e-07  3.663247e-08
# x1_quantile  7.767609e-04  9.669046e-01
# Determinant of the Correlation Matrix (D): 0.05913007531094847

# %%
file_path = 'METHOD_5_SCALE_DIFF.xlsx'  # 替换为你的文件路径
df1 = pd.read_excel(file_path)
print(PC(df1))
# Compute condition index
cond_index, max_condition_index = calculate_condition_index(df1)
print(cond_index)
print(max_condition_index)
r = calculate_vif1(df1)
print(r)
vd_df = calculate_variance_decomposition(df1)
print(vd_df)
D = calculate_determinant_of_correlation_matrix(df1)
print("Determinant of the Correlation Matrix (D):", D)
# Out:
#           x1        x2        x3        x4         y
# x1  1.000000  0.886747  0.891387  0.900302  0.976288
# x2  0.886747  1.000000  0.885052  0.900011  0.956386
# x3  0.891387  0.885052  1.000000  0.926413  0.946169
# x4  0.900302  0.900011  0.926413  1.000000  0.944224
# y   0.976288  0.956386  0.946169  0.944224  1.000000
#    Eigenvalue  Condition Index
# 0    4.686248         1.000000
# 1    0.125844         6.102340
# 2    0.114779         6.389707
# 3    0.072884         8.018580
# 4    0.000245       138.268131
# 138.26813095442876
#   Variable          VIF
# 0       x1   691.826025
# 1       x2   302.023868
# 2       x3   122.657413
# 3       x4    16.374948
# 4        y  2977.322900
#     Eigenvalue_1  Eigenvalue_2  Eigenvalue_3  Eigenvalue_4  Eigenvalue_5
# x1      0.951914      0.000433      0.041666      0.005776      0.000211
# x2      0.915587      0.000197      0.072935      0.011265      0.000016
# x3      0.896425      0.000174      0.001589      0.092284      0.009529
# x4      0.893270      0.000023      0.003458      0.032851      0.070398
# y       0.999986      0.000001      0.000006      0.000004      0.000002
# Determinant of the Correlation Matrix (D): 1.2092954824822808e-06

# %% [markdown]
# Determinant 不是好的选择
